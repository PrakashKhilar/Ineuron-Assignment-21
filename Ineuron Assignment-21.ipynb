# %% [markdown]
# # Ineuron Assignment-21

# %% [markdown]
# SUBMITTED BY : PRAAKSH KHILAR

# %%
# Q1 : Add the current date to the text file today.txt as a string.

# %%
# Ans;

import datetime
# Code to Add current date to the today.txt file
file = open('today.txt','w')
file.write(datetime.datetime.now().strftime("%d-%m-%Y"))
file.close()
# Code to Read current date from today.txt file
file = open('today.txt','r')
print(file.read())
file.close()
# Out:
# 13-07-2022

# %%
# Q2 : Read the text file today.txt into the string today_string

# %%
# Ans ;

file = open('today.txt','r')
today_string = file.read()
print(today_string)
# Out:
# 13-07-2022

# %%
# Q3 : Parse the date from today_string.

# %%
# Ans;

from datetime import datetime
parsed_data = datetime.strptime(today_string, '%d-%m-%Y')
print(parsed_data)
# Out:
# 2022-07-13 00:00:00

# %%
# Q4 :  List the files in your current directory.

# %%
# Ans;

import os
for folders, subfolders, files in os.walk(os.getcwd()):
    for file in files:
        print(file)
# Out:
# # 4 June Resivion Class.ipynb
# # Ineuron Assignment-17.ipynb
# --Print Receipt--.pdf
# 05 June - Functions & Lambda Functions (1).ipynb
# 05 June - Functions & Lambda Functions.ipynb
# 1. WEBSITE ADVERTISEMENT.pdf
# 1.csv
# 11794_q2.pdf
# 120 Data Science Interview Questions Guide.pdf
# 2022-06-20 02_40_41.81.ScanFile.pdf
# 2022_23_AWES_REPORT.xlsx
# 21-22 new admission.xls
# 4a9dedcc-b2f3-4512-a27b-a8324fd8803d.docx
# AccessionStoreUpdateTemplate (1).xlsx
# AccessionStoreUpdateTemplate.xlsx
# AccountStatement_20220610103746.xls
# Adobe Scan 22-Jun-2022 (2).pdf
# AllStudentsList.xlsx
# AmountSetupOneTime.xlsx
# AmountSetupRecurring.xlsx
# Analytics and Data Science Jobs in India.pdf
# ANITA_BANK_DETAILS.jpeg
# APS AHMEDANAGAR CR INVOICE.pdf
# APS FAZILKA CR INVOICE.pdf
# APS HISAR CR INVOICE.pdf
# APS JORHAT CR INVOICE.pdf
# APS KANPUR CR INVOICE.pdf
# APS LUCKNOW CR INVOICE.pdf
# APS MEERUT CR INVOICE.pdf
# APS MHOW CR INVOICE.pdf
# APS NAHAN CR INVOICE.pdf
# APS RANCHI CR INVOICE.pdf
# APS SAUGOR CR INVOICE.pdf
# APS SRI GANGANAGAR CR INVOICE.pdf
# APS SURATGARH CR INVOICE.pdf
# APSDHK_2021_22_HUM_XII_J_ACTIVE_TC.pdf
# APSDHK_2021_22_HUM_XII_K_ACTIVE_TC.pdf
# APSDHK_2021_22_HUM_XII_K_TC_TC.pdf
# APSDHK_2021_22_HUM_XII_L_ACTIVE_TC.pdf
# APSDHK_2021_22_HUM_XII_TC_TC.pdf
# APSDHK_2021_22_SCI_XII_A_ACTIVE_TC.pdf
# APSDHK_2021_22_SCI_XII_C_ACTIVE_TC.pdf
# Assignment_10.docx
# Assignment_15 (1).docx
# Assignment_15 (2).docx
# Assignment_15.docx
# Assignment_16.docx
# Assignment_17.docx
# Assignment_18.docx
# Assignment_19.docx
# Assignment_20.docx
# Assignment_9.docx
# Attendance_report.xlsx
# BIKASH_DUPLICATE_FEE.xlsx
# books.db
# BUS FEE SHOWN DOUBLE IN DUE REGISTER AS ON 01 JULY 2022.xlsx
# Capture.JPG
# Collection Report (1).xlsx
# Collection Report (2).xlsx
# Collection Report (3).xlsx
# Collection Report.xlsx
# Copy of OnlinePaymentVerificationReport.xlsx
# data-1657011713927.csv
# data-1657011736425.csv
# data-1657011750463.csv
# DEEPAK_DUPLICATE_FEE.xlsx
# desktop.ini
# DIFFERENCE IN DUE REPORT  AND COLLECTION REPORT FROM 01 APRIL 2022 TO 30 APRIL 2022.xlsx
# Digi-Training-APS Bolarum.pdf
# Digicamp Issue (28-09-2020).xlsx
# DOB_ASSIGN.xlsx
# DOUBLE_ENTRY_LIST_IN_SESSION_2022-23(1).xlsx
# DOUBLE_ENTRY_LIST_IN_SESSION_2022-23.xlsx
# DueReport (1).xlsx
# DueReport (10).xlsx
# DueReport (11).xlsx
# DueReport (12).xlsx
# DueReport (13).xlsx
# DueReport (2).xlsx
# DueReport (3).xlsx
# DueReport (4).xlsx
# DueReport (5).xlsx
# DueReport (6).xlsx
# DueReport (7).xlsx
# DueReport (8).xlsx
# DueReport (9).xlsx
# DueReport(12).xlsx
# DueReport(3)(1).xlsx
# DueReport(3).xlsx
# DueReport(4).xlsx
# DueReport.xlsx
# FBS INVOICE.pdf
# FEE SHOWN DOUBLE IN DUE REGISTER AS ON 27 JUNE 2022.xlsx
# feeReceipt (1).pdf
# feeReceipt (2) (1).pdf
# feeReceipt (2).pdf
# feeReceipt (3).pdf
# feeReceipt (8).pdf
# feeReceipt(1).pdf
# feeReceipt(2).pdf
# feeReceipt.pdf
# Git Cheatsheet.pdf
# Grievance Report(06-Jun-2022)(1).xls
# Grievance Report(06-Jun-2022).xls
# Grievance Report(12-Jul-2022)(1).xls
# Grievance Report(12-Jul-2022).xls
# Grievance Report(16-Jun-2022).xls
# Grievance Report(20-Jun-2022).xls
# image.png
# Ineuron Assignment - 11.ipynb
# Ineuron Assignment - 12.ipynb
# Ineuron Assignment - 14.ipynb
# Ineuron Assignment - 18.ipynb
# Ineuron Assignment - 19 (1).ipynb
# Ineuron Assignment - 19.ipynb
# Ineuron Assignment - 20 (1).ipynb
# Ineuron Assignment - 20.ipynb
# Ineuron Assignment - 7 (1).ipynb
# Ineuron Assignment - 7 (2).ipynb
# Ineuron Assignment - 7 (3).ipynb
# Ineuron Assignment - 7.ipynb
# Ineuron Assignment - 8.ipynb
# Ineuron Assignment -13.ipynb
# Ineuron Assignment -16.ipynb
# Ineuron Assignment-15.ipynb
# Ineuron Assignment-21.ipynb
# Ineuron Assignment-9.ipynb
# Ineuron Assignmnet - 10 (1).ipynb
# Ineuron Assignmnet - 10.ipynb
# Institute wise Strength Report (1).xlsx
# Institute wise Strength Report(1).xlsx
# Institute wise Strength Report.xlsx
# Institute wise Strength Report_APRIL_2022.xlsx
# Institute wise Strength Report_JUNE_2022.xlsx
# Institute wise Strength Report_MAY_2022.xlsx
# Iterator, generator, map, reduce, filter, basic file operation.ipynb
# Key_REDSHIELD_ARMY_PRE_PRIMARY_SCHOOL.pdf
# LibraryTemplate (1).xlsx
# LibraryTemplate(1).xlsx
# LibraryTemplate(2).xlsx
# LibraryTemplate.xlsx
# list of students whose fee due is double and 2 studetents in RED COLOUR whose due fee is 4 times (1).xlsx
# list of students whose fee due is double and 2 studetents in RED COLOUR whose due fee is 4 times.xlsx
# Mentality.pdf
# OnlinePaymentVerificationReport (1).xlsx
# OnlinePaymentVerificationReport.xlsx
# PRAKASH CHANDRA KHILAR BXKPK5956P_2022-23(1).pdf
# PRAKASH CHANDRA KHILAR BXKPK5956P_2022-23.pdf
# pycharm-community-2022.1.3.exe
# REOPENED_Grievance Report(11-Jun-2022).xls
# reportcard_HUMT_XII__1268.pdf
# Salary Upload Template.xls
# Salary_PaySlip_2017.zip
# SANTOSH_DUPLICATE_FEE.xlsx
# Silicon TechLab Pvt.Ltd Mail - Re VAS - Security Audit Completed(PAYU) - Army Public School Pune - 4 - Tid - 9024156 - Part 1.pdf
# storytelling-with-data-cole-nussbaumer-knaflic (1).pdf
# StudentDues (1).xlsx
# StudentDues (2).xlsx
# StudentDues.xlsx
# Student_details.csv
# Student_details.xlsx
# STU_CERTIFICATE_PDF.pdf
# test.pdf
# test.txt
# today.txt
# Untitled.ipynb
# Untitled.png
# Updated AWES Agreement.docx
# WhatsApp Image 2022-06-09 at 9.42.08 AM (1).jpeg
# WhatsApp Image 2022-06-09 at 9.42.08 AM.jpeg
# WhatsApp Image 2022-06-10 at 9.49.54 PM (1).jpeg
# WhatsApp Image 2022-06-10 at 9.49.54 PM.jpeg
# WhatsApp Image 2022-06-13 at 9.15.25 AM.jpeg
# WhatsApp Image 2022-06-16 at 9.39.16 AM.jpeg
# WhatsApp Image 2022-06-24 at 5.38.39 PM.jpeg
# WhatsApp Image 2022-07-02 at 12.08.16 PM.jpeg
# WhatsApp Image 2022-07-02 at 12.08.28 PM.jpeg
# WhatsApp Image 2022-07-04 at 5.11.49 PM.jpeg
# WhatsApp Image 2022-07-04 at 5.14.12 PM.jpeg
# WhatsApp Image 2022-07-04 at 5.15.18 PM.jpeg
# WhatsApp Video 2022-06-13 at 4.13.55 PM.mp4
# WhatsApp Video 2022-06-16 at 11.27.58 AM.mp4
# ~$AccessionStoreUpdateTemplate (1).xlsx
# ~$AllStudentsList (7).xlsx
# ~$avneet.docx
# ~$binar No 6 (31 May - 04 Jun 21) Skills & Life Skills Devp.docx
# ~$CONS GROUP TERM REPORT(XI-XII).xlsx
# ~$d Schedule Webinar No 5 (24-25 May & 27-28 May 21) Tech Digi Campus LMS (1).docx
# ~$d Schedule Webinar No 5 (24-25 May & 27-28 May 21) Tech Digi Campus LMS (3).docx
# ~$dget Module.docx
# ~$Discount Report (1).xlsx
# ~$Doc1.docx
# ~$ES-Letter 1.2.docx
# ~$gi Campus REview.docx
# ~$GICAMP ISSUES AS ON 11.06.21.docx
# ~$gicamp.docx
# ~$OMOTION_LISTCLASS_XI_2019-20_JUNE_for_DIGICAMP_.docx
# ~$pendix-AA.doc
# ~$pendix-B.doc
# ~$RC CLASS XI.xlsx
# ~$Salary_Sheet_Details.xlsx
# ~$signment_3.docx
# ~$ubonee (1).doc
# ~$ubonee.doc
# ~$ubonee.docx
# ~WRL3548.tmp
# # 4 June Resivion Class-checkpoint.ipynb
# 05 June - Functions & Lambda Functions (1)-checkpoint.ipynb
# 05 June - Functions & Lambda Functions-checkpoint.ipynb
# Ineuron Assignment - 19-checkpoint.ipynb
# Ineuron Assignment - 20-checkpoint.ipynb
# Ineuron Assignment-21-checkpoint.ipynb
# Untitled-checkpoint.ipynb
# Salary_PaySlip_April.pdf
# Salary_PaySlip_March.pdf
# Salary_PaySlip_May.pdf

# %%
# Q5 : Create a list of all of the files in your parent directory (minimum five files should be available).

# %%
# Ans ;

import os 
os.listdir()
# Out:
# ['# 4 June Resivion Class.ipynb',
#  '# Ineuron Assignment-17.ipynb',
#  '--Print Receipt--.pdf',
#  '.ipynb_checkpoints',
#  '05 June - Functions & Lambda Functions (1).ipynb',
#  '05 June - Functions & Lambda Functions.ipynb',
#  '1. WEBSITE ADVERTISEMENT.pdf',
#  '1.csv',
#  '11794_q2.pdf',
#  '120 Data Science Interview Questions Guide.pdf',
#  '2022-06-20 02_40_41.81.ScanFile.pdf',
#  '2022_23_AWES_REPORT.xlsx',
#  '21-22 new admission.xls',
#  '4a9dedcc-b2f3-4512-a27b-a8324fd8803d.docx',
#  'AccessionStoreUpdateTemplate (1).xlsx',
#  'AccessionStoreUpdateTemplate.xlsx',
#  'AccountStatement_20220610103746.xls',
#  'Adobe Scan 22-Jun-2022 (2).pdf',
#  'AllStudentsList.xlsx',
#  'AmountSetupOneTime.xlsx',
#  'AmountSetupRecurring.xlsx',
#  'Analytics and Data Science Jobs in India.pdf',
#  'ANITA_BANK_DETAILS.jpeg',
#  'APS AHMEDANAGAR CR INVOICE.pdf',
#  'APS FAZILKA CR INVOICE.pdf',
#  'APS HISAR CR INVOICE.pdf',
#  'APS JORHAT CR INVOICE.pdf',
#  'APS KANPUR CR INVOICE.pdf',
#  'APS LUCKNOW CR INVOICE.pdf',
#  'APS MEERUT CR INVOICE.pdf',
#  'APS MHOW CR INVOICE.pdf',
#  'APS NAHAN CR INVOICE.pdf',
#  'APS RANCHI CR INVOICE.pdf',
#  'APS SAUGOR CR INVOICE.pdf',
#  'APS SRI GANGANAGAR CR INVOICE.pdf',
#  'APS SURATGARH CR INVOICE.pdf',
#  'APSDHK_2021_22_HUM_XII_J_ACTIVE_TC.pdf',
#  'APSDHK_2021_22_HUM_XII_K_ACTIVE_TC.pdf',
#  'APSDHK_2021_22_HUM_XII_K_TC_TC.pdf',
#  'APSDHK_2021_22_HUM_XII_L_ACTIVE_TC.pdf',
#  'APSDHK_2021_22_HUM_XII_TC_TC.pdf',
#  'APSDHK_2021_22_SCI_XII_A_ACTIVE_TC.pdf',
#  'APSDHK_2021_22_SCI_XII_C_ACTIVE_TC.pdf',
#  'Assignment_10.docx',
#  'Assignment_15 (1).docx',
#  'Assignment_15 (2).docx',
#  'Assignment_15.docx',
#  'Assignment_16.docx',
#  'Assignment_17.docx',
#  'Assignment_18.docx',
#  'Assignment_19.docx',
#  'Assignment_20.docx',
#  'Assignment_9.docx',
#  'Attendance_report.xlsx',
#  'BIKASH_DUPLICATE_FEE.xlsx',
#  'books.db',
#  'BUS FEE SHOWN DOUBLE IN DUE REGISTER AS ON 01 JULY 2022.xlsx',
#  'Capture.JPG',
#  'Collection Report (1).xlsx',
#  'Collection Report (2).xlsx',
#  'Collection Report (3).xlsx',
#  'Collection Report.xlsx',
#  'Copy of OnlinePaymentVerificationReport.xlsx',
#  'data-1657011713927.csv',
#  'data-1657011736425.csv',
#  'data-1657011750463.csv',
#  'DEEPAK_DUPLICATE_FEE.xlsx',
#  'desktop.ini',
#  'DIFFERENCE IN DUE REPORT  AND COLLECTION REPORT FROM 01 APRIL 2022 TO 30 APRIL 2022.xlsx',
#  'Digi-Training-APS Bolarum.pdf',
#  'Digicamp Issue (28-09-2020).xlsx',
#  'DOB_ASSIGN.xlsx',
#  'DOUBLE_ENTRY_LIST_IN_SESSION_2022-23(1).xlsx',
#  'DOUBLE_ENTRY_LIST_IN_SESSION_2022-23.xlsx',
#  'DueReport (1).xlsx',
#  'DueReport (10).xlsx',
#  'DueReport (11).xlsx',
#  'DueReport (12).xlsx',
#  'DueReport (13).xlsx',
#  'DueReport (2).xlsx',
#  'DueReport (3).xlsx',
#  'DueReport (4).xlsx',
#  'DueReport (5).xlsx',
#  'DueReport (6).xlsx',
#  'DueReport (7).xlsx',
#  'DueReport (8).xlsx',
#  'DueReport (9).xlsx',
#  'DueReport(12).xlsx',
#  'DueReport(3)(1).xlsx',
#  'DueReport(3).xlsx',
#  'DueReport(4).xlsx',
#  'DueReport.xlsx',
#  'FBS INVOICE.pdf',
#  'FEE SHOWN DOUBLE IN DUE REGISTER AS ON 27 JUNE 2022.xlsx',
#  'feeReceipt (1).pdf',
#  'feeReceipt (2) (1).pdf',
#  'feeReceipt (2).pdf',
#  'feeReceipt (3).pdf',
#  'feeReceipt (8).pdf',
#  'feeReceipt(1).pdf',
#  'feeReceipt(2).pdf',
#  'feeReceipt.pdf',
#  'Git Cheatsheet.pdf',
#  'Grievance Report(06-Jun-2022)(1).xls',
#  'Grievance Report(06-Jun-2022).xls',
#  'Grievance Report(12-Jul-2022)(1).xls',
#  'Grievance Report(12-Jul-2022).xls',
#  'Grievance Report(16-Jun-2022).xls',
#  'Grievance Report(20-Jun-2022).xls',
#  'image.png',
#  'Ineuron Assignment - 11.ipynb',
#  'Ineuron Assignment - 12.ipynb',
#  'Ineuron Assignment - 14.ipynb',
#  'Ineuron Assignment - 18.ipynb',
#  'Ineuron Assignment - 19 (1).ipynb',
#  'Ineuron Assignment - 19.ipynb',
#  'Ineuron Assignment - 20 (1).ipynb',
#  'Ineuron Assignment - 20.ipynb',
#  'Ineuron Assignment - 7 (1).ipynb',
#  'Ineuron Assignment - 7 (2).ipynb',
#  'Ineuron Assignment - 7 (3).ipynb',
#  'Ineuron Assignment - 7.ipynb',
#  'Ineuron Assignment - 8.ipynb',
#  'Ineuron Assignment -13.ipynb',
#  'Ineuron Assignment -16.ipynb',
#  'Ineuron Assignment-15.ipynb',
#  'Ineuron Assignment-21.ipynb',
#  'Ineuron Assignment-9.ipynb',
#  'Ineuron Assignmnet - 10 (1).ipynb',
#  'Ineuron Assignmnet - 10.ipynb',
#  'Institute wise Strength Report (1).xlsx',
#  'Institute wise Strength Report(1).xlsx',
#  'Institute wise Strength Report.xlsx',
#  'Institute wise Strength Report_APRIL_2022.xlsx',
#  'Institute wise Strength Report_JUNE_2022.xlsx',
#  'Institute wise Strength Report_MAY_2022.xlsx',
#  'Iterator, generator, map, reduce, filter, basic file operation.ipynb',
#  'Key_REDSHIELD_ARMY_PRE_PRIMARY_SCHOOL.pdf',
#  'LibraryTemplate (1).xlsx',
#  'LibraryTemplate(1).xlsx',
#  'LibraryTemplate(2).xlsx',
#  'LibraryTemplate.xlsx',
#  'list of students whose fee due is double and 2 studetents in RED COLOUR whose due fee is 4 times (1).xlsx',
#  'list of students whose fee due is double and 2 studetents in RED COLOUR whose due fee is 4 times.xlsx',
#  'Mentality.pdf',
#  'OnlinePaymentVerificationReport (1).xlsx',
#  'OnlinePaymentVerificationReport.xlsx',
#  'PRAKASH CHANDRA KHILAR BXKPK5956P_2022-23(1).pdf',
#  'PRAKASH CHANDRA KHILAR BXKPK5956P_2022-23.pdf',
#  'pycharm-community-2022.1.3.exe',
#  'REOPENED_Grievance Report(11-Jun-2022).xls',
#  'reportcard_HUMT_XII__1268.pdf',
#  'Salary Upload Template.xls',
#  'Salary_PaySlip_2017',
#  'Salary_PaySlip_2017.zip',
#  'SANTOSH_DUPLICATE_FEE.xlsx',
#  'Silicon TechLab Pvt.Ltd Mail - Re VAS - Security Audit Completed(PAYU) - Army Public School Pune - 4 - Tid - 9024156 - Part 1.pdf',
#  'storytelling-with-data-cole-nussbaumer-knaflic (1).pdf',
#  'StudentDues (1).xlsx',
#  'StudentDues (2).xlsx',
#  'StudentDues.xlsx',
#  'Student_details.csv',
#  'Student_details.xlsx',
#  'STU_CERTIFICATE_PDF.pdf',
#  'test.pdf',
#  'test.txt',
#  'today.txt',
#  'Untitled.ipynb',
#  'Untitled.png',
#  'Updated AWES Agreement.docx',
#  'WhatsApp Image 2022-06-09 at 9.42.08 AM (1).jpeg',
#  'WhatsApp Image 2022-06-09 at 9.42.08 AM.jpeg',
#  'WhatsApp Image 2022-06-10 at 9.49.54 PM (1).jpeg',
#  'WhatsApp Image 2022-06-10 at 9.49.54 PM.jpeg',
#  'WhatsApp Image 2022-06-13 at 9.15.25 AM.jpeg',
#  'WhatsApp Image 2022-06-16 at 9.39.16 AM.jpeg',
#  'WhatsApp Image 2022-06-24 at 5.38.39 PM.jpeg',
#  'WhatsApp Image 2022-07-02 at 12.08.16 PM.jpeg',
#  'WhatsApp Image 2022-07-02 at 12.08.28 PM.jpeg',
#  'WhatsApp Image 2022-07-04 at 5.11.49 PM.jpeg',
#  'WhatsApp Image 2022-07-04 at 5.14.12 PM.jpeg',
#  'WhatsApp Image 2022-07-04 at 5.15.18 PM.jpeg',
#  'WhatsApp Video 2022-06-13 at 4.13.55 PM.mp4',
#  'WhatsApp Video 2022-06-16 at 11.27.58 AM.mp4',
#  '~$AccessionStoreUpdateTemplate (1).xlsx',
#  '~$AllStudentsList (7).xlsx',
#  '~$avneet.docx',
#  '~$binar No 6 (31 May - 04 Jun 21) Skills & Life Skills Devp.docx',
#  '~$CONS GROUP TERM REPORT(XI-XII).xlsx',
#  '~$d Schedule Webinar No 5 (24-25 May & 27-28 May 21) Tech Digi Campus LMS (1).docx',
#  '~$d Schedule Webinar No 5 (24-25 May & 27-28 May 21) Tech Digi Campus LMS (3).docx',
#  '~$dget Module.docx',
#  '~$Discount Report (1).xlsx',
#  '~$Doc1.docx',
#  '~$ES-Letter 1.2.docx',
#  '~$gi Campus REview.docx',
#  '~$GICAMP ISSUES AS ON 11.06.21.docx',
#  '~$gicamp.docx',
#  '~$OMOTION_LISTCLASS_XI_2019-20_JUNE_for_DIGICAMP_.docx',
#  '~$pendix-AA.doc',
#  '~$pendix-B.doc',
#  '~$RC CLASS XI.xlsx',
#  '~$Salary_Sheet_Details.xlsx',
#  '~$signment_3.docx',
#  '~$ubonee (1).doc',
#  '~$ubonee.doc',
#  '~$ubonee.docx',
#  '~WRL3548.tmp']

# %%
# Q6 : Use multiprocessing to create three separate processes.
#      Make each one wait a random number of seconds between one and five, print the current time, and then exit.

# %%
# Ans ;


import multiprocessing
import time 
import random
import datetime

def procOne():
    print(f'Proc_one_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_one_Endtime -> {datetime.datetime.now()}')
    
def procTwo():
    print(f'Proc_two_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_two_Endtime -> {datetime.datetime.now()}')

def procThree():
    print(f'Proc_two_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_two_Endtime -> {datetime.datetime.now()}')
    
if __name__ == "__main__":    
    p1 = multiprocessing.Process(target=procOne)
    p2 = multiprocessing.Process(target=procTwo)
    p3 = multiprocessing.Process(target=procThree)

    p1.start()
    p2.start()
    p3.start()

    p1.join()
    p2.join()
    p3.join()

# %%
# Q7 : Create a date object of your day of birth.

# %%
# Ans;

from datetime import datetime
my_dob = datetime.strptime('17/03/1984','%d/%m/%Y')
print(my_dob, type(my_dob))
# Out:
# 1984-03-17 00:00:00 <class 'datetime.datetime'>

# %%
# Q8 :  What day of the week was your day of birth?

# %%
# Ans ;

from datetime import datetime
my_dob = datetime(1984,3,17)
my_dob.strftime("%A")
# Out:
# 'Saturday'

# %%
# Q9 :  When will you be (or when were you) 10,000 days old?

# %%
# Ans ;
from datetime import datetime, timedelta
my_dob = datetime.strptime("17/03/1984",'%d/%m/%Y')
future_date = my_dob-timedelta(10000)
future_date
# Out:
# datetime.datetime(1956, 10, 30, 0, 0)
